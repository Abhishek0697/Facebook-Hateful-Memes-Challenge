# %%
import tensorflow as tf

# You'll generate plots of attention in order to see which parts of an image
# our model focuses on during captioning
import matplotlib.pyplot as plt

# Scikit-learn includes many helpful utilities
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

import collections
import random
import re
import numpy as np
import os
import time
import json
from glob import glob
from PIL import Image
import pickle

# %%
# Download caption annotation files
annotation_folder = '/annotations/'
if not os.path.exists(os.path.abspath('.') + annotation_folder):
  annotation_zip = tf.keras.utils.get_file('captions.zip',
                                          cache_subdir=os.path.abspath('.'),
                                          origin = 'http://images.cocodataset.org/annotations/annotations_trainval2014.zip',
                                          extract = True)
  annotation_file = os.path.dirname(annotation_zip)+'/annotations/captions_train2014.json'
  os.remove(annotation_zip)

# Download image files
image_folder = '/train2014/'
if not os.path.exists(os.path.abspath('.') + image_folder):
  image_zip = tf.keras.utils.get_file('train2014.zip',
                                      cache_subdir=os.path.abspath('.'),
                                      origin = 'http://images.cocodataset.org/zips/train2014.zip',
                                      extract = True)
  PATH = os.path.dirname(image_zip) + image_folder
  os.remove(image_zip)
else:
  PATH = os.path.abspath('.') + image_folder
# Out:
# Downloading data from http://images.cocodataset.org/annotations/annotations_trainval2014.zip
# 252878848/252872794 [==============================] - 3s 0us/step

# %%
import json
tweets_training = []
for line in open('data/train.jsonl', 'r'):
    tweets_training.append(json.loads(line))
    
for line in open('data/dev_seen.jsonl', 'r'):
    tweets_training.append(json.loads(line))
    
for line in open('data/dev_unseen.jsonl', 'r'):
    tweets_training.append(json.loads(line))
    

with open(annotation_file, 'r') as f:
    annotations = json.load(f)

# Group all captions together having the same image ID.
image_path_to_caption = collections.defaultdict(list)

for item in tweets_training:
    if item['label'] == 0:
        val1 = item["img"]
        val2 = item['text']
        caption = f"<start> {val2} <end>"
        image_path = 'data/' + val1
        image_path_to_caption[image_path].append(caption)
        
        
for val in annotations['annotations']:
  caption = f"<start> {val['caption']} <end>"
  image_path = PATH + 'COCO_train2014_' + '%012d.jpg' % (val['image_id'])
  image_path_to_caption[image_path].append(caption)

image_paths = list(image_path_to_caption.keys())
random.shuffle(image_paths)

# Select the first 6000 image_paths from the shuffled set.
# Approximately each image id has 5 captions associated with it, so that will 
# lead to 30,000 examples.
train_image_paths = image_paths
print(len(train_image_paths))
# Out:
# 88657

# %%
import json
tweets_training = []
for line in open('data/train.jsonl', 'r'):
    tweets_training.append(json.loads(line))
    
for line in open('data/dev_seen.jsonl', 'r'):
    tweets_training.append(json.loads(line))
    
for line in open('data/dev_unseen.jsonl', 'r'):
    tweets_training.append(json.loads(line))
    

image_path_to_caption = collections.defaultdict(list)   
for item in tweets_training:
    if item['label'] == 0:
        val1 = item["img"]
        val2 = item['text']
        caption = f"<start> {val2} <end>"
        image_path = 'data/' + val1
        image_path_to_caption[image_path].append(caption)
        
image_paths = list(image_path_to_caption.keys())
random.shuffle(image_paths)

train_image_paths = image_paths
print(len(train_image_paths))

# %%
train_captions = []
img_name_vector = []

for image_path in train_image_paths:
  caption_list = image_path_to_caption[image_path]
  train_captions.extend(caption_list)
  img_name_vector.extend([image_path] * len(caption_list))

print(train_captions[0])
Image.open(img_name_vector[0])
# Out:
# <start> A home office with a desk covered in various electronics and accessories. <end>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x7FC17E5C2E90>

# %%
print(train_captions)

# %%
def load_image(image_path):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, (299, 299))
    img = tf.keras.applications.inception_v3.preprocess_input(img)
    return img, image_path

# %%
image_model = tf.keras.applications.InceptionV3(include_top=False,
                                                weights='imagenet')
new_input = image_model.input
hidden_layer = image_model.layers[-1].output

image_features_extract_model = tf.keras.Model(new_input, hidden_layer)

# %%
tf.__version__
# Out:
# '2.0.0'

# %%
# Get unique images
encode_train = sorted(set(img_name_vector))

# Feel free to change batch_size according to your system configuration
image_dataset = tf.data.Dataset.from_tensor_slices(encode_train)
image_dataset = image_dataset.map(
  load_image, num_parallel_calls=tf.data.experimental.AUTOTUNE).batch(16)

for img, path in image_dataset:
  batch_features = image_features_extract_model(img)
  batch_features = tf.reshape(batch_features,
                              (batch_features.shape[0], -1, batch_features.shape[3]))

  for bf, p in zip(batch_features, path):
    path_of_feature = p.numpy().decode("utf-8")
    np.save(path_of_feature, bf.numpy())

# %%
# Find the maximum length of any caption in our dataset
def calc_max_length(tensor):
    return max(len(t) for t in tensor)

# Choose the top 5000 words from the vocabulary
top_k = 10000
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=top_k,
                                                  oov_token="<unk>",
                                                  filters='!"#$%&()*+.,-/:;=?@[\]^_`{|}~ ')
tokenizer.fit_on_texts(train_captions)
train_seqs = tokenizer.texts_to_sequences(train_captions)

tokenizer.word_index['<pad>'] = 0
tokenizer.index_word[0] = '<pad>'

# Create the tokenized vectors
train_seqs = tokenizer.texts_to_sequences(train_captions)

# Pad each vector to the max_length of the captions
# If you do not provide a max_length value, pad_sequences calculates it automatically
cap_vector = tf.keras.preprocessing.sequence.pad_sequences(train_seqs, padding='post')

# Calculates the max_length, which is used to store the attention weights
max_length = calc_max_length(train_seqs)

# %%
train_seqs

# %%
img_to_cap_vector = collections.defaultdict(list)
for img, cap in zip(img_name_vector, cap_vector):
  img_to_cap_vector[img].append(cap)

# Create training and validation sets using an 80-20 split randomly.
img_keys = list(img_to_cap_vector.keys())
random.shuffle(img_keys)

slice_index = int(len(img_keys)*0.8)
img_name_train_keys, img_name_val_keys = img_keys[:slice_index], img_keys[slice_index:]

img_name_train = []
cap_train = []
for imgt in img_name_train_keys:
  capt_len = len(img_to_cap_vector[imgt])
  img_name_train.extend([imgt] * capt_len)
  cap_train.extend(img_to_cap_vector[imgt])

img_name_val = []
cap_val = []
for imgv in img_name_val_keys:
  capv_len = len(img_to_cap_vector[imgv])
  img_name_val.extend([imgv] * capv_len)
  cap_val.extend(img_to_cap_vector[imgv])

# %%
len(img_name_train), len(cap_train), len(img_name_val), len(cap_val)
# Out:
# (336213, 336213, 83974, 83974)

# %%
# Feel free to change these parameters according to your system's configuration

BATCH_SIZE = 64
BUFFER_SIZE = 1000
embedding_dim = 256
units = 512
vocab_size = top_k + 1
num_steps = len(img_name_train) // BATCH_SIZE
# Shape of the vector extracted from InceptionV3 is (64, 2048)
# These two variables represent that vector shape
features_shape = 2048
attention_features_shape = 64

# Load the numpy files
def map_func(img_name, cap):
  img_tensor = np.load(img_name.decode('utf-8')+'.npy')
  return img_tensor, cap

# %%
dataset = tf.data.Dataset.from_tensor_slices((img_name_train, cap_train))

# Use map to load the numpy files in parallel
dataset = dataset.map(lambda item1, item2: tf.numpy_function(
          map_func, [item1, item2], [tf.float32, tf.int32]),
          num_parallel_calls=tf.data.experimental.AUTOTUNE)

# Shuffle and batch
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# %%
class BahdanauAttention(tf.keras.Model):
  def __init__(self, units):
    super(BahdanauAttention, self).__init__()
    self.W1 = tf.keras.layers.Dense(units)
    self.W2 = tf.keras.layers.Dense(units)
    self.V = tf.keras.layers.Dense(1)

  def call(self, features, hidden):
    # features(CNN_encoder output) shape == (batch_size, 64, embedding_dim)

    # hidden shape == (batch_size, hidden_size)
    # hidden_with_time_axis shape == (batch_size, 1, hidden_size)
    hidden_with_time_axis = tf.expand_dims(hidden, 1)

    # attention_hidden_layer shape == (batch_size, 64, units)
    attention_hidden_layer = (tf.nn.tanh(self.W1(features) +
                                         self.W2(hidden_with_time_axis)))

    # score shape == (batch_size, 64, 1)
    # This gives you an unnormalized score for each image feature.
    score = self.V(attention_hidden_layer)

    # attention_weights shape == (batch_size, 64, 1)
    attention_weights = tf.nn.softmax(score, axis=1)

    # context_vector shape after sum == (batch_size, hidden_size)
    context_vector = attention_weights * features
    context_vector = tf.reduce_sum(context_vector, axis=1)

    return context_vector, attention_weights

# %%
class CNN_Encoder(tf.keras.Model):
    # Since you have already extracted the features and dumped it using pickle
    # This encoder passes those features through a Fully connected layer
    def __init__(self, embedding_dim):
        super(CNN_Encoder, self).__init__()
        # shape after fc == (batch_size, 64, embedding_dim)
        self.fc = tf.keras.layers.Dense(embedding_dim)

    def call(self, x):
        x = self.fc(x)
        x = tf.nn.relu(x)
        return x

# %%
class RNN_Decoder(tf.keras.Model):
  def __init__(self, embedding_dim, units, vocab_size):
    super(RNN_Decoder, self).__init__()
    self.units = units

    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc1 = tf.keras.layers.Dense(self.units)
    self.fc2 = tf.keras.layers.Dense(vocab_size)

    self.attention = BahdanauAttention(self.units)

  def call(self, x, features, hidden):
    # defining attention as a separate model
    context_vector, attention_weights = self.attention(features, hidden)

    # x shape after passing through embedding == (batch_size, 1, embedding_dim)
    x = self.embedding(x)

    # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
    x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

    # passing the concatenated vector to the GRU
    output, state = self.gru(x)

    # shape == (batch_size, max_length, hidden_size)
    x = self.fc1(output)

    # x shape == (batch_size * max_length, hidden_size)
    x = tf.reshape(x, (-1, x.shape[2]))

    # output shape == (batch_size * max_length, vocab)
    x = self.fc2(x)

    return x, state, attention_weights

  def reset_state(self, batch_size):
    return tf.zeros((batch_size, self.units))

# %%
encoder = CNN_Encoder(embedding_dim)
decoder = RNN_Decoder(embedding_dim, units, vocab_size)

optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %%
checkpoint_path = "./checkpoints/train"
ckpt = tf.train.Checkpoint(encoder=encoder,
                           decoder=decoder,
                           optimizer = optimizer)
ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

start_epoch = 0
if ckpt_manager.latest_checkpoint:
  start_epoch = int(ckpt_manager.latest_checkpoint.split('-')[-1])
  # restoring the latest checkpoint in checkpoint_path
  ckpt.restore(ckpt_manager.latest_checkpoint)

# %%
if ckpt_manager.latest_checkpoint:
    print('hello')

# %%
# adding this in a separate cell because if you run the training cell
# many times, the loss_plot array will be reset
loss_plot = []

# %%
@tf.function
def train_step(img_tensor, target):
  loss = 0

  # initializing the hidden state for each batch
  # because the captions are not related from image to image
  hidden = decoder.reset_state(batch_size=target.shape[0])

  dec_input = tf.expand_dims([tokenizer.word_index['<start>']] * target.shape[0], 1)

  with tf.GradientTape() as tape:
      features = encoder(img_tensor)

      for i in range(1, target.shape[1]):
          # passing the features through the decoder
          predictions, hidden, _ = decoder(dec_input, features, hidden)

          loss += loss_function(target[:, i], predictions)

          # using teacher forcing
          dec_input = tf.expand_dims(target[:, i], 1)

  total_loss = (loss / int(target.shape[1]))

  trainable_variables = encoder.trainable_variables + decoder.trainable_variables

  gradients = tape.gradient(loss, trainable_variables)

  optimizer.apply_gradients(zip(gradients, trainable_variables))

  return loss, total_loss

# %%
print(vocab_size)
# Out:
# 10001

# %%
EPOCHS = 10
start_epoch = 0
for epoch in range(start_epoch, EPOCHS):
    start = time.time()
    total_loss = 0
    
    for (batch, (img_tensor, target)) in enumerate(dataset):
        batch_loss, t_loss = train_step(img_tensor, target)
        total_loss += t_loss
        
        if batch % 100 == 0:
            print ('Epoch {} Batch {} Loss {:.4f}'.format(
              epoch + 1, batch, batch_loss.numpy() / int(target.shape[1])))
    # storing the epoch end loss value to plot later
    loss_plot.append(total_loss / num_steps)

    if epoch % 5 == 0:
      ckpt_manager.save()

    print ('Epoch {} Loss {:.6f}'.format(epoch + 1,
                                         total_loss/num_steps))
    print ('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 1.4631
# Epoch 1 Batch 100 Loss 0.7622
# Epoch 1 Batch 200 Loss 0.6923
# Epoch 1 Batch 300 Loss 0.6669
# Epoch 1 Batch 400 Loss 0.6437
# Epoch 1 Batch 500 Loss 0.5736
# Epoch 1 Batch 600 Loss 0.5387
# Epoch 1 Batch 700 Loss 0.5549
# Epoch 1 Batch 800 Loss 0.5642
# Epoch 1 Batch 900 Loss 0.4726
# Epoch 1 Batch 1000 Loss 0.4881
# Epoch 1 Batch 1100 Loss 0.5094
# Epoch 1 Batch 1200 Loss 0.5098
# Epoch 1 Batch 1300 Loss 0.5349
# Epoch 1 Batch 1400 Loss 0.5150
# Epoch 1 Batch 1500 Loss 0.4871
# Epoch 1 Batch 1600 Loss 0.5155
# Epoch 1 Batch 1700 Loss 0.5029
# Epoch 1 Batch 1800 Loss 0.5067
# Epoch 1 Batch 1900 Loss 0.5052
# Epoch 1 Batch 2000 Loss 0.5025
# Epoch 1 Batch 2100 Loss 0.5341
# Epoch 1 Batch 2200 Loss 0.4538
# Epoch 1 Batch 2300 Loss 0.5025
# Epoch 1 Batch 2400 Loss 0.5011
# Epoch 1 Batch 2500 Loss 0.5081
# Epoch 1 Batch 2600 Loss 0.4566
# Epoch 1 Batch 2700 Loss 0.4746
# Epoch 1 Batch 2800 Loss 0.4681
# Epoch 1 Batch 2900 Loss 0.5038
# Epoch 1 Batch 3000 Loss 0.5375
# Epoch 1 Batch 3100 Loss 0.4994
# Epoch 1 Batch 3200 Loss 0.4980
# Epoch 1 Batch 3300 Loss 0.4422
# Epoch 1 Batch 3400 Loss 0.4968
# Epoch 1 Batch 3500 Loss 0.5030
# Epoch 1 Batch 3600 Loss 0.4781
# Epoch 1 Batch 3700 Loss 0.4385
# Epoch 1 Batch 3800 Loss 0.4082
# Epoch 1 Batch 3900 Loss 0.4661
# Epoch 1 Batch 4000 Loss 0.4624
# Epoch 1 Batch 4100 Loss 0.4517
# Epoch 1 Batch 4200 Loss 0.4768
# Epoch 1 Batch 4300 Loss 0.4314
# Epoch 1 Batch 4400 Loss 0.4201
# Epoch 1 Batch 4500 Loss 0.4671
# Epoch 1 Batch 4600 Loss 0.4614
# Epoch 1 Batch 4700 Loss 0.4824
# Epoch 1 Batch 4800 Loss 0.4835
# Epoch 1 Batch 4900 Loss 0.4513
# Epoch 1 Batch 5000 Loss 0.4758
# Epoch 1 Batch 5100 Loss 0.4896
# Epoch 1 Batch 5200 Loss 0.4419
# Epoch 1 Loss 0.510713
# Time taken for 1 epoch 1594.4681873321533 sec
#
# Epoch 2 Batch 0 Loss 0.4776
# Epoch 2 Batch 100 Loss 0.5063
# Epoch 2 Batch 200 Loss 0.4968
# Epoch 2 Batch 300 Loss 0.4847
# Epoch 2 Batch 400 Loss 0.4775
# Epoch 2 Batch 500 Loss 0.4256
# Epoch 2 Batch 600 Loss 0.4692
# Epoch 2 Batch 700 Loss 0.3950
# Epoch 2 Batch 800 Loss 0.4509
# Epoch 2 Batch 900 Loss 0.4195
# Epoch 2 Batch 1000 Loss 0.4291
# Epoch 2 Batch 1100 Loss 0.4917
# Epoch 2 Batch 1200 Loss 0.4137
# Epoch 2 Batch 1300 Loss 0.4318
# Epoch 2 Batch 1400 Loss 0.4510
# Epoch 2 Batch 1500 Loss 0.4514
# Epoch 2 Batch 1600 Loss 0.4406
# Epoch 2 Batch 1700 Loss 0.4445
# Epoch 2 Batch 1800 Loss 0.4609
# Epoch 2 Batch 1900 Loss 0.4440
# Epoch 2 Batch 2000 Loss 0.4252
# Epoch 2 Batch 2100 Loss 0.4607
# Epoch 2 Batch 2200 Loss 0.4627
# Epoch 2 Batch 2300 Loss 0.4602
# Epoch 2 Batch 2400 Loss 0.4284
# Epoch 2 Batch 2500 Loss 0.5152
# Epoch 2 Batch 2600 Loss 0.4329
# Epoch 2 Batch 2700 Loss 0.4283
# Epoch 2 Batch 2800 Loss 0.4599
# Epoch 2 Batch 2900 Loss 0.4276
# Epoch 2 Batch 3000 Loss 0.4882
# Epoch 2 Batch 3100 Loss 0.4477
# Epoch 2 Batch 3200 Loss 0.4682
# Epoch 2 Batch 3300 Loss 0.4540
# Epoch 2 Batch 3400 Loss 0.4883
# Epoch 2 Batch 3500 Loss 0.4157
# Epoch 2 Batch 3600 Loss 0.4070
# Epoch 2 Batch 3700 Loss 0.4213
# Epoch 2 Batch 3800 Loss 0.4272
# Epoch 2 Batch 3900 Loss 0.4296
# Epoch 2 Batch 4000 Loss 0.4042
# Epoch 2 Batch 4100 Loss 0.4703
# Epoch 2 Batch 4200 Loss 0.4318
# Epoch 2 Batch 4300 Loss 0.4159
# Epoch 2 Batch 4400 Loss 0.4363
# Epoch 2 Batch 4500 Loss 0.4048
# Epoch 2 Batch 4600 Loss 0.4589
# Epoch 2 Batch 4700 Loss 0.4504
# Epoch 2 Batch 4800 Loss 0.4315
# Epoch 2 Batch 4900 Loss 0.3975
# Epoch 2 Batch 5000 Loss 0.4225
# Epoch 2 Batch 5100 Loss 0.4174
# Epoch 2 Batch 5200 Loss 0.4899
# Epoch 2 Loss 0.440751
# Time taken for 1 epoch 1442.7289879322052 sec
#
# Epoch 3 Batch 0 Loss 0.4474
# Epoch 3 Batch 100 Loss 0.4114
# Epoch 3 Batch 200 Loss 0.4036
# Epoch 3 Batch 300 Loss 0.4212
# Epoch 3 Batch 400 Loss 0.4287
# Epoch 3 Batch 500 Loss 0.4182
# Epoch 3 Batch 600 Loss 0.4492
# Epoch 3 Batch 700 Loss 0.4370
# Epoch 3 Batch 800 Loss 0.4180
# Epoch 3 Batch 900 Loss 0.4690
# Epoch 3 Batch 1000 Loss 0.3803
# Epoch 3 Batch 1100 Loss 0.4186
# Epoch 3 Batch 1200 Loss 0.4621
# Epoch 3 Batch 1300 Loss 0.3817
# Epoch 3 Batch 1400 Loss 0.4115
# Epoch 3 Batch 1500 Loss 0.4277
# Epoch 3 Batch 1600 Loss 0.4472
# Epoch 3 Batch 1700 Loss 0.4047
# Epoch 3 Batch 1800 Loss 0.4252
# Epoch 3 Batch 1900 Loss 0.3981
# Epoch 3 Batch 2000 Loss 0.3768
# Epoch 3 Batch 2100 Loss 0.4281
# Epoch 3 Batch 2200 Loss 0.4140
# Epoch 3 Batch 2300 Loss 0.4652
# Epoch 3 Batch 2400 Loss 0.4284
# Epoch 3 Batch 2500 Loss 0.4132
# Epoch 3 Batch 2600 Loss 0.4593
# Epoch 3 Batch 2700 Loss 0.3929
# Epoch 3 Batch 2800 Loss 0.3984
# Epoch 3 Batch 2900 Loss 0.4423
# Epoch 3 Batch 3000 Loss 0.4263
# Epoch 3 Batch 3100 Loss 0.3843
# Epoch 3 Batch 3200 Loss 0.4007
# Epoch 3 Batch 3300 Loss 0.4333
# Epoch 3 Batch 3400 Loss 0.4071
# Epoch 3 Batch 3500 Loss 0.4440
# Epoch 3 Batch 3600 Loss 0.4058
# Epoch 3 Batch 3700 Loss 0.3998
# Epoch 3 Batch 3800 Loss 0.4029
# Epoch 3 Batch 3900 Loss 0.4151
# Epoch 3 Batch 4000 Loss 0.3747
# Epoch 3 Batch 4100 Loss 0.3821
# Epoch 3 Batch 4200 Loss 0.4106
# Epoch 3 Batch 4300 Loss 0.4064
# Epoch 3 Batch 4400 Loss 0.3974
# Epoch 3 Batch 4500 Loss 0.4362
# Epoch 3 Batch 4600 Loss 0.4399
# Epoch 3 Batch 4700 Loss 0.4501
# Epoch 3 Batch 4800 Loss 0.4272
# Epoch 3 Batch 4900 Loss 0.5051
# Epoch 3 Batch 5000 Loss 0.4257
# Epoch 3 Batch 5100 Loss 0.4487
# Epoch 3 Batch 5200 Loss 0.4178
# Epoch 3 Loss 0.419617
# Time taken for 1 epoch 1447.4005467891693 sec
#
# Epoch 4 Batch 0 Loss 0.4286
# Epoch 4 Batch 100 Loss 0.4160
# Epoch 4 Batch 200 Loss 0.3664
# Epoch 4 Batch 300 Loss 0.4087
# Epoch 4 Batch 400 Loss 0.4265
# Epoch 4 Batch 500 Loss 0.3845
# Epoch 4 Batch 600 Loss 0.4297
# Epoch 4 Batch 700 Loss 0.4394
# Epoch 4 Batch 800 Loss 0.4108
# Epoch 4 Batch 900 Loss 0.4500
# Epoch 4 Batch 1000 Loss 0.4763
# Epoch 4 Batch 1100 Loss 0.4206
# Epoch 4 Batch 1200 Loss 0.3633
# Epoch 4 Batch 1300 Loss 0.3685
# Epoch 4 Batch 1400 Loss 0.4083
# Epoch 4 Batch 1500 Loss 0.3673
# Epoch 4 Batch 1600 Loss 0.3874
# Epoch 4 Batch 1700 Loss 0.4539
# Epoch 4 Batch 1800 Loss 0.4227
# Epoch 4 Batch 1900 Loss 0.3683
# Epoch 4 Batch 2000 Loss 0.3841
# Epoch 4 Batch 2100 Loss 0.3637
# Epoch 4 Batch 2200 Loss 0.4000
# Epoch 4 Batch 2300 Loss 0.3982
# Epoch 4 Batch 2400 Loss 0.4230
# Epoch 4 Batch 2500 Loss 0.4074
# Epoch 4 Batch 2600 Loss 0.4253
# Epoch 4 Batch 2700 Loss 0.3951
# Epoch 4 Batch 2800 Loss 0.3914
# Epoch 4 Batch 2900 Loss 0.4185
# Epoch 4 Batch 3000 Loss 0.4512
# Epoch 4 Batch 3100 Loss 0.3812
# Epoch 4 Batch 3200 Loss 0.3602
# Epoch 4 Batch 3300 Loss 0.4099
# Epoch 4 Batch 3400 Loss 0.4318
# Epoch 4 Batch 3500 Loss 0.4335
# Epoch 4 Batch 3600 Loss 0.3678
# Epoch 4 Batch 3700 Loss 0.3858
# Epoch 4 Batch 3800 Loss 0.4210
# Epoch 4 Batch 3900 Loss 0.3745
# Epoch 4 Batch 4000 Loss 0.4414
# Epoch 4 Batch 4100 Loss 0.4087
# Epoch 4 Batch 4200 Loss 0.4021
# Epoch 4 Batch 4300 Loss 0.3877
# Epoch 4 Batch 4400 Loss 0.3998
# Epoch 4 Batch 4500 Loss 0.4225
# Epoch 4 Batch 4600 Loss 0.4066
# Epoch 4 Batch 4700 Loss 0.4223
# Epoch 4 Batch 4800 Loss 0.3851
# Epoch 4 Batch 4900 Loss 0.3724
# Epoch 4 Batch 5000 Loss 0.3874
# Epoch 4 Batch 5100 Loss 0.3986
# Epoch 4 Batch 5200 Loss 0.4116
# Epoch 4 Loss 0.404982
# Time taken for 1 epoch 1444.6041915416718 sec
#
# Epoch 5 Batch 0 Loss 0.3742
# Epoch 5 Batch 100 Loss 0.3637
# Epoch 5 Batch 200 Loss 0.3935
# Epoch 5 Batch 300 Loss 0.3994
# Epoch 5 Batch 400 Loss 0.3924
# Epoch 5 Batch 500 Loss 0.3785
# Epoch 5 Batch 600 Loss 0.3927
# Epoch 5 Batch 700 Loss 0.4175
# Epoch 5 Batch 800 Loss 0.3945
# Epoch 5 Batch 900 Loss 0.3728
# Epoch 5 Batch 1000 Loss 0.4043
# Epoch 5 Batch 1100 Loss 0.4118
# Epoch 5 Batch 1200 Loss 0.3844
# Epoch 5 Batch 1300 Loss 0.3737
# Epoch 5 Batch 1400 Loss 0.3598
# Epoch 5 Batch 1500 Loss 0.3677
# Epoch 5 Batch 1600 Loss 0.3836
# Epoch 5 Batch 1700 Loss 0.3805
# Epoch 5 Batch 1800 Loss 0.4265
# Epoch 5 Batch 1900 Loss 0.3885
# Epoch 5 Batch 2000 Loss 0.3729
# Epoch 5 Batch 2100 Loss 0.3892
# Epoch 5 Batch 2200 Loss 0.3885
# Epoch 5 Batch 2300 Loss 0.3646
# Epoch 5 Batch 2400 Loss 0.3648
# Epoch 5 Batch 2500 Loss 0.4631
# Epoch 5 Batch 2600 Loss 0.3834
# Epoch 5 Batch 2700 Loss 0.3925
# Epoch 5 Batch 2800 Loss 0.4193
# Epoch 5 Batch 2900 Loss 0.4063
# Epoch 5 Batch 3000 Loss 0.3428
# Epoch 5 Batch 3100 Loss 0.3689
# Epoch 5 Batch 3200 Loss 0.3661
# Epoch 5 Batch 3300 Loss 0.3957
# Epoch 5 Batch 3400 Loss 0.4107
# Epoch 5 Batch 3500 Loss 0.4063
# Epoch 5 Batch 3600 Loss 0.3830
# Epoch 5 Batch 3700 Loss 0.3862
# Epoch 5 Batch 3800 Loss 0.4053
# Epoch 5 Batch 3900 Loss 0.3808
# Epoch 5 Batch 4000 Loss 0.3405
# Epoch 5 Batch 4100 Loss 0.4077
# Epoch 5 Batch 4200 Loss 0.3692
# Epoch 5 Batch 4300 Loss 0.3924
# Epoch 5 Batch 4400 Loss 0.4154
# Epoch 5 Batch 4500 Loss 0.3811
# Epoch 5 Batch 4600 Loss 0.3920
# Epoch 5 Batch 4700 Loss 0.3514
# Epoch 5 Batch 4800 Loss 0.3763
# Epoch 5 Batch 4900 Loss 0.3834
# Epoch 5 Batch 5000 Loss 0.4319
# Epoch 5 Batch 5100 Loss 0.4017
# Epoch 5 Batch 5200 Loss 0.4077
# Epoch 5 Loss 0.393132
# Time taken for 1 epoch 1445.7165479660034 sec
#
# Epoch 6 Batch 0 Loss 0.4083
# Epoch 6 Batch 100 Loss 0.3927
# Epoch 6 Batch 200 Loss 0.4167
# Epoch 6 Batch 300 Loss 0.3962
# Epoch 6 Batch 400 Loss 0.3702
# Epoch 6 Batch 500 Loss 0.3839
# Epoch 6 Batch 600 Loss 0.4084
# Epoch 6 Batch 700 Loss 0.3616
# Epoch 6 Batch 800 Loss 0.3753
# Epoch 6 Batch 900 Loss 0.3650
# Epoch 6 Batch 1000 Loss 0.3691
# Epoch 6 Batch 1100 Loss 0.3612
# Epoch 6 Batch 1200 Loss 0.3255
# Epoch 6 Batch 1300 Loss 0.3730
# Epoch 6 Batch 1400 Loss 0.3760
# Epoch 6 Batch 1500 Loss 0.3548
# Epoch 6 Batch 1600 Loss 0.3775
# Epoch 6 Batch 1700 Loss 0.3836
# Epoch 6 Batch 1800 Loss 0.3961
# Epoch 6 Batch 1900 Loss 0.3814
# Epoch 6 Batch 2000 Loss 0.3509
# Epoch 6 Batch 2100 Loss 0.3689
# Epoch 6 Batch 2200 Loss 0.3883
# Epoch 6 Batch 2300 Loss 0.3577
# Epoch 6 Batch 2400 Loss 0.4051
# Epoch 6 Batch 2500 Loss 0.4032
# Epoch 6 Batch 2600 Loss 0.3795
# Epoch 6 Batch 2700 Loss 0.3760
# Epoch 6 Batch 2800 Loss 0.4021
# Epoch 6 Batch 2900 Loss 0.3753
# Epoch 6 Batch 3000 Loss 0.4058
# Epoch 6 Batch 3100 Loss 0.3696
# Epoch 6 Batch 3200 Loss 0.3936
# Epoch 6 Batch 3300 Loss 0.3694
# Epoch 6 Batch 3400 Loss 0.3711
# Epoch 6 Batch 3500 Loss 0.4054
# Epoch 6 Batch 3600 Loss 0.3797
# Epoch 6 Batch 3700 Loss 0.3681
# Epoch 6 Batch 3800 Loss 0.3915
# Epoch 6 Batch 3900 Loss 0.4038
# Epoch 6 Batch 4000 Loss 0.3632
# Epoch 6 Batch 4100 Loss 0.4190
# Epoch 6 Batch 4200 Loss 0.4110
# Epoch 6 Batch 4300 Loss 0.3578
# Epoch 6 Batch 4400 Loss 0.3734
# Epoch 6 Batch 4500 Loss 0.3732
# Epoch 6 Batch 4600 Loss 0.4219
# Epoch 6 Batch 4700 Loss 0.4169
# Epoch 6 Batch 4800 Loss 0.3347
# Epoch 6 Batch 4900 Loss 0.3853
# Epoch 6 Batch 5000 Loss 0.3773
# Epoch 6 Batch 5100 Loss 0.3960
# Epoch 6 Batch 5200 Loss 0.3601
# Epoch 6 Loss 0.383228
# Time taken for 1 epoch 1446.1235802173615 sec
#
# Epoch 7 Batch 0 Loss 0.3694
# Epoch 7 Batch 100 Loss 0.3672
# Epoch 7 Batch 200 Loss 0.4043
# Epoch 7 Batch 300 Loss 0.4180
# Epoch 7 Batch 400 Loss 0.4068
# Epoch 7 Batch 500 Loss 0.4199
# Epoch 7 Batch 600 Loss 0.3866
# Epoch 7 Batch 700 Loss 0.3993
# Epoch 7 Batch 800 Loss 0.4146
# Epoch 7 Batch 900 Loss 0.3486
# Epoch 7 Batch 1000 Loss 0.3514
# Epoch 7 Batch 1100 Loss 0.3656
# Epoch 7 Batch 1200 Loss 0.3830
# Epoch 7 Batch 1300 Loss 0.3740
# Epoch 7 Batch 1400 Loss 0.3412
# Epoch 7 Batch 1500 Loss 0.3815
# Epoch 7 Batch 1600 Loss 0.4372
# Epoch 7 Batch 1700 Loss 0.3432
# Epoch 7 Batch 1800 Loss 0.3725
# Epoch 7 Batch 1900 Loss 0.3717
# Epoch 7 Batch 2000 Loss 0.3913
# Epoch 7 Batch 2100 Loss 0.4160
# Epoch 7 Batch 2200 Loss 0.3670
# Epoch 7 Batch 2300 Loss 0.3940
# Epoch 7 Batch 2400 Loss 0.3773
# Epoch 7 Batch 2500 Loss 0.3939
# Epoch 7 Batch 2600 Loss 0.3812
# Epoch 7 Batch 2700 Loss 0.3584
# Epoch 7 Batch 2800 Loss 0.3928
# Epoch 7 Batch 2900 Loss 0.4019
# Epoch 7 Batch 3000 Loss 0.3719
# Epoch 7 Batch 3100 Loss 0.3725
# Epoch 7 Batch 3200 Loss 0.3772
# Epoch 7 Batch 3300 Loss 0.3667
# Epoch 7 Batch 3400 Loss 0.4080
# Epoch 7 Batch 3500 Loss 0.3739
# Epoch 7 Batch 3600 Loss 0.3920
# Epoch 7 Batch 3700 Loss 0.3759
# Epoch 7 Batch 3800 Loss 0.3650
# Epoch 7 Batch 3900 Loss 0.3355
# Epoch 7 Batch 4000 Loss 0.3868
# Epoch 7 Batch 4100 Loss 0.3724
# Epoch 7 Batch 4200 Loss 0.3432
# Epoch 7 Batch 4300 Loss 0.3793
# Epoch 7 Batch 4400 Loss 0.3414
# Epoch 7 Batch 4500 Loss 0.4370
# Epoch 7 Batch 4600 Loss 0.3708
# Epoch 7 Batch 4700 Loss 0.3554
# Epoch 7 Batch 4800 Loss 0.3951
# Epoch 7 Batch 4900 Loss 0.4129
# Epoch 7 Batch 5000 Loss 0.3364
# Epoch 7 Batch 5100 Loss 0.3906
# Epoch 7 Batch 5200 Loss 0.3818
# Epoch 7 Loss 0.374300
# Time taken for 1 epoch 1445.976254940033 sec
#
# Epoch 8 Batch 0 Loss 0.3422
# Epoch 8 Batch 100 Loss 0.3622
# Epoch 8 Batch 200 Loss 0.3568
# Epoch 8 Batch 300 Loss 0.3763
# Epoch 8 Batch 400 Loss 0.3754
# Epoch 8 Batch 500 Loss 0.3775
# Epoch 8 Batch 600 Loss 0.3779
# Epoch 8 Batch 700 Loss 0.3574
# Epoch 8 Batch 800 Loss 0.3475
# Epoch 8 Batch 900 Loss 0.3456
# Epoch 8 Batch 1000 Loss 0.3347
# Epoch 8 Batch 1100 Loss 0.3837
# Epoch 8 Batch 1200 Loss 0.3858
# Epoch 8 Batch 1300 Loss 0.3913
# Epoch 8 Batch 1400 Loss 0.3477
# Epoch 8 Batch 1500 Loss 0.3751
# Epoch 8 Batch 1600 Loss 0.3558
# Epoch 8 Batch 1700 Loss 0.3753
# Epoch 8 Batch 1800 Loss 0.3815
# Epoch 8 Batch 1900 Loss 0.3686
# Epoch 8 Batch 2000 Loss 0.3447
# Epoch 8 Batch 2100 Loss 0.3655
# Epoch 8 Batch 2200 Loss 0.3861
# Epoch 8 Batch 2300 Loss 0.3293
# Epoch 8 Batch 2400 Loss 0.3204
# Epoch 8 Batch 2500 Loss 0.3364
# Epoch 8 Batch 2600 Loss 0.3781
# Epoch 8 Batch 2700 Loss 0.3564
# Epoch 8 Batch 2800 Loss 0.3812
# Epoch 8 Batch 2900 Loss 0.3697
# Epoch 8 Batch 3000 Loss 0.3529
# Epoch 8 Batch 3100 Loss 0.3720
# Epoch 8 Batch 3200 Loss 0.3567
# Epoch 8 Batch 3300 Loss 0.3572
# Epoch 8 Batch 3400 Loss 0.3767
# Epoch 8 Batch 3500 Loss 0.3463
# Epoch 8 Batch 3600 Loss 0.3831
# Epoch 8 Batch 3700 Loss 0.3663
# Epoch 8 Batch 3800 Loss 0.3409
# Epoch 8 Batch 3900 Loss 0.3737
# Epoch 8 Batch 4000 Loss 0.3800
# Epoch 8 Batch 4100 Loss 0.3307
# Epoch 8 Batch 4200 Loss 0.3804
# Epoch 8 Batch 4300 Loss 0.3566
# Epoch 8 Batch 4400 Loss 0.3750
# Epoch 8 Batch 4500 Loss 0.3325
# Epoch 8 Batch 4600 Loss 0.4006
# Epoch 8 Batch 4700 Loss 0.3327
# Epoch 8 Batch 4800 Loss 0.3566
# Epoch 8 Batch 4900 Loss 0.3543
# Epoch 8 Batch 5000 Loss 0.3830
# Epoch 8 Batch 5100 Loss 0.3495
# Epoch 8 Batch 5200 Loss 0.3834
# Epoch 8 Loss 0.366714
# Time taken for 1 epoch 1445.768156528473 sec
#
# Epoch 9 Batch 0 Loss 0.3745
# Epoch 9 Batch 100 Loss 0.4001
# Epoch 9 Batch 200 Loss 0.3497
# Epoch 9 Batch 300 Loss 0.3639
# Epoch 9 Batch 400 Loss 0.3562
# Epoch 9 Batch 500 Loss 0.3608
# Epoch 9 Batch 600 Loss 0.3739
# Epoch 9 Batch 700 Loss 0.3587
# Epoch 9 Batch 800 Loss 0.3703
# Epoch 9 Batch 900 Loss 0.3751
# Epoch 9 Batch 1000 Loss 0.3876
# Epoch 9 Batch 1100 Loss 0.3418
# Epoch 9 Batch 1200 Loss 0.3413
# Epoch 9 Batch 1300 Loss 0.3694
# Epoch 9 Batch 1400 Loss 0.3465
# Epoch 9 Batch 1500 Loss 0.3618
# Epoch 9 Batch 1600 Loss 0.3879
# Epoch 9 Batch 1700 Loss 0.3987
# Epoch 9 Batch 1800 Loss 0.3819
# Epoch 9 Batch 1900 Loss 0.3751
# Epoch 9 Batch 2000 Loss 0.3457
# Epoch 9 Batch 2100 Loss 0.3551
# Epoch 9 Batch 2200 Loss 0.3359
# Epoch 9 Batch 2300 Loss 0.3471
# Epoch 9 Batch 2400 Loss 0.3646
# Epoch 9 Batch 2500 Loss 0.4009
# Epoch 9 Batch 2600 Loss 0.3382
# Epoch 9 Batch 2700 Loss 0.3260
# Epoch 9 Batch 2800 Loss 0.3815
# Epoch 9 Batch 2900 Loss 0.3881
# Epoch 9 Batch 3000 Loss 0.3612
# Epoch 9 Batch 3100 Loss 0.3724
# Epoch 9 Batch 3200 Loss 0.3639
# Epoch 9 Batch 3300 Loss 0.3601
# Epoch 9 Batch 3400 Loss 0.3624
# Epoch 9 Batch 3500 Loss 0.3568
# Epoch 9 Batch 3600 Loss 0.3682
# Epoch 9 Batch 3700 Loss 0.3691
# Epoch 9 Batch 3800 Loss 0.3301
# Epoch 9 Batch 3900 Loss 0.3622
# Epoch 9 Batch 4000 Loss 0.3532
# Epoch 9 Batch 4100 Loss 0.3394
# Epoch 9 Batch 4200 Loss 0.3642
# Epoch 9 Batch 4300 Loss 0.3758
# Epoch 9 Batch 4400 Loss 0.3485
# Epoch 9 Batch 4500 Loss 0.3931
# Epoch 9 Batch 4600 Loss 0.3346
# Epoch 9 Batch 4700 Loss 0.3922
# Epoch 9 Batch 4800 Loss 0.3464
# Epoch 9 Batch 4900 Loss 0.3537
# Epoch 9 Batch 5000 Loss 0.3190
# Epoch 9 Batch 5100 Loss 0.3647
# Epoch 9 Batch 5200 Loss 0.3626
# Epoch 9 Loss 0.360223
# Time taken for 1 epoch 1447.1618316173553 sec
#
# Epoch 10 Batch 0 Loss 0.3335
# Epoch 10 Batch 100 Loss 0.3323
# Epoch 10 Batch 200 Loss 0.3546
# Epoch 10 Batch 300 Loss 0.3779
# Epoch 10 Batch 400 Loss 0.4279
# Epoch 10 Batch 500 Loss 0.3729
# Epoch 10 Batch 600 Loss 0.3127
# Epoch 10 Batch 700 Loss 0.3814
# Epoch 10 Batch 800 Loss 0.3529
# Epoch 10 Batch 900 Loss 0.3531
# Epoch 10 Batch 1000 Loss 0.3752
# Epoch 10 Batch 1100 Loss 0.3340
# Epoch 10 Batch 1200 Loss 0.3272
# Epoch 10 Batch 1300 Loss 0.3668
# Epoch 10 Batch 1400 Loss 0.3203
# Epoch 10 Batch 1500 Loss 0.3381
# Epoch 10 Batch 1600 Loss 0.3244
# Epoch 10 Batch 1700 Loss 0.3621
# Epoch 10 Batch 1800 Loss 0.3635
# Epoch 10 Batch 1900 Loss 0.3595
# Epoch 10 Batch 2000 Loss 0.3565
# Epoch 10 Batch 2100 Loss 0.3732
# Epoch 10 Batch 2200 Loss 0.3319
# Epoch 10 Batch 2300 Loss 0.3427
# Epoch 10 Batch 2400 Loss 0.3727
# Epoch 10 Batch 2500 Loss 0.3617
# Epoch 10 Batch 2600 Loss 0.3549
# Epoch 10 Batch 2700 Loss 0.3466
# Epoch 10 Batch 2800 Loss 0.3858
# Epoch 10 Batch 2900 Loss 0.3258
# Epoch 10 Batch 3000 Loss 0.3315
# Epoch 10 Batch 3100 Loss 0.3979
# Epoch 10 Batch 3200 Loss 0.3336
# Epoch 10 Batch 3300 Loss 0.3456
# Epoch 10 Batch 3400 Loss 0.3563
# Epoch 10 Batch 3500 Loss 0.3674
# Epoch 10 Batch 3600 Loss 0.3608
# Epoch 10 Batch 3700 Loss 0.3312
# Epoch 10 Batch 3800 Loss 0.3699
# Epoch 10 Batch 3900 Loss 0.4043
# Epoch 10 Batch 4000 Loss 0.3724
# Epoch 10 Batch 4100 Loss 0.3775
# Epoch 10 Batch 4200 Loss 0.3426
# Epoch 10 Batch 4300 Loss 0.3362
# Epoch 10 Batch 4400 Loss 0.3406
# Epoch 10 Batch 4500 Loss 0.3369
# Epoch 10 Batch 4600 Loss 0.3467
# Epoch 10 Batch 4700 Loss 0.3402
# Epoch 10 Batch 4800 Loss 0.3540
# Epoch 10 Batch 4900 Loss 0.3492
# Epoch 10 Batch 5000 Loss 0.3614
# Epoch 10 Batch 5100 Loss 0.3593
# Epoch 10 Batch 5200 Loss 0.3430
# Epoch 10 Loss 0.354210
# Time taken for 1 epoch 1447.2343537807465 sec

# %%
plt.plot(loss_plot)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Plot')
plt.show()

# %%
def evaluate(image):
    attention_plot = np.zeros((max_length, attention_features_shape))

    hidden = decoder.reset_state(batch_size=1)

    temp_input = tf.expand_dims(load_image(image)[0], 0)
    img_tensor_val = image_features_extract_model(temp_input)
    img_tensor_val = tf.reshape(img_tensor_val, (img_tensor_val.shape[0], -1, img_tensor_val.shape[3]))

    features = encoder(img_tensor_val)

    dec_input = tf.expand_dims([tokenizer.word_index['<start>']], 0)
    result = []

    for i in range(max_length):
        predictions, hidden, attention_weights = decoder(dec_input, features, hidden)

        attention_plot[i] = tf.reshape(attention_weights, (-1, )).numpy()

        predicted_id = tf.random.categorical(predictions, 1)[0][0].numpy()
        result.append(tokenizer.index_word[predicted_id])

        if tokenizer.index_word[predicted_id] == '<end>':
            return result, attention_plot

        dec_input = tf.expand_dims([predicted_id], 0)

    attention_plot = attention_plot[:len(result), :]
    return result, attention_plot

# %%
def plot_attention(image, result, attention_plot):
    temp_image = np.array(Image.open(image))

    fig = plt.figure(figsize=(10, 10))

    len_result = len(result)
    for l in range(len_result):
        temp_att = np.resize(attention_plot[l], (8, 8))
        ax = fig.add_subplot(len_result//2, len_result//2, l+1)
        ax.set_title(result[l])
        img = ax.imshow(temp_image)
        ax.imshow(temp_att, cmap='gray', alpha=0.6, extent=img.get_extent())

    plt.tight_layout()
    plt.show()

# %%
# captions on the validation set
rid = np.random.randint(0, len(img_name_val))
image = img_name_val[rid]
real_caption = ' '.join([tokenizer.index_word[i] for i in cap_val[rid] if i not in [0]])
result, attention_plot = evaluate(image)

print ('Real Caption:', real_caption)
print ('Prediction Caption:', ' '.join(result))
plot_attention(image, result, attention_plot)
# Out:
# Real Caption: <start> some zebras tall brown grass bushes and trees <end>
# Prediction Caption: two zebras and frolicking in the background <end>

# %%
image_url = 'https://tensorflow.org/images/surf.jpg'
image_extension = image_url[-4:]
image_path = tf.keras.utils.get_file('image'+image_extension,
                                     origin=image_url)

result, attention_plot = evaluate(image_path)
print ('Prediction Caption:', ' '.join(result))
plot_attention(image_path, result, attention_plot)
# opening the image
Image.open(image_path)

# %%
import json
tweets = []
for line in open('data/dev_seen.jsonl', 'r'):
    tweets.append(json.loads(line))

# %%
#import json
tweets_train = []
for line in open('data/train.jsonl', 'r'):
    tweets_train.append(json.loads(line))

# %%
f = open('training_complete_list.txt','w')
bada = []
for item in tweets_train:
    val1 = item["img"]
    val2 = item['label']
    val3 = item['text']
    image_path = 'data/' + val1
    result, attention_plot = evaluate(image_path)
    bada.append(result)

# %%
len(tokenizer.index_word.keys())

# %%
#f = open('training_complete_list.txt','w')
i = 0
for item in tweets_train:
    val1 = item["img"]
    val2 = item['label']
    val3 = item['text']
    image_path = 'data/' + val1
    
    final = ' '.join(bada[i][:-1])
    final = final.replace('<unk> ', '')
    final = final.replace('\n', '')
    i += 1
    f.write(val1 + '\t' + val3 + '\t' + final + '\t' + str(val2) +'\n')
    
f.close()

# %%
bada_list = []
for item in tweets:
    val1 = item["img"]
    val2 = item['label']
    val3 = item['text']
    image_path = 'data/' + val1
    result, attention_plot = evaluate(image_path)
    bada_list.append(result)

# %%
f = open('validate_complete_list.txt','w')
i = 0
for item in tweets:
    val1 = item["img"]
    val2 = item['label']
    val3 = item['text']
    image_path = 'data/' + val1
    final = ' '.join(bada_list[i][:-1])
    final = final.replace('<unk> ', '')
    final = final.replace('\n', '')

    i += 1  
    f.write(val1 + '\t' + val3 + '\t' + final + '\t' + str(val2) +'\n')
    
f.close()

# %%
tweets_test = []
for line in open('data/test_seen.jsonl', 'r'):
    tweets_test.append(json.loads(line))

# %%
bada_test = []
for item in tweets_test:
    val1 = item["img"]
    val3 = item['text']
    image_path = 'data/' + val1
    result, attention_plot = evaluate(image_path)
    bada_test.append(result)

# %%
f = open('test_complete_list.txt','w')

i = 0
for item in tweets_test:
    val1 = item["img"]
    val3 = item['text']
    image_path = 'data/' + val1
    
    final = ' '.join(bada_test[i][:-1])
    final = final.replace('<unk> ', '')
    final = final.replace('\n', '')
    i += 1
    f.write(val1 + '\t' + val3 + '\t' + final +'\n')
    
f.close()

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !cp drive/My\ Drive/MultiModal/Lnmwdnq3YcF7F3YsJncp.zip .

# %%
# !unzip -P KexZs4tn8hujn1nK Lnmwdnq3YcF7F3YsJncp.zip

# %%
image_path = 'data/img/70914.png'

result, attention_plot = evaluate(image_path)
print ('Prediction Caption:', ' '.join(result))
plot_attention(image_path, result, attention_plot)
# opening the image
Image.open(image_path)
